# %% [markdown]
# ## Word2Vec 词向量
# 用`skip-gram`的方法来预测词间的关系。黄文坚、唐源的`tensorflow 实战`也是采用的这个例子。

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# - 下载数据集，此数据集为一个文本数据集。

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# - 读取文本数据集，并按词存储为`words`元组。

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
print(' '.join(words[0:100]))
# Out:
# Data size 17005207
# anarchism originated as a term of abuse first used against early working class radicals including the diggers of the english revolution and the sans culottes of the french revolution whilst the term is still used in a pejorative way to describe any act that used violent means to destroy the organization of society it has also been taken up as a positive label by self defined anarchists the word anarchism is derived from the greek without archons ruler chief king anarchism as a political philosophy is the belief that rulers are unnecessary and should be abolished although there are differing

# %% [markdown]
# - 提取词频前`vocabulary_size`的单词，其余单词记作`UNK`
# - 得到`words`的位置表示`data`，单词和单词数目的表示`count`，单词和单词位置的表示和反表示`dictionary`, `reverse_dictionary`

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# - ![](https://git.ustclug.org/Charles/web_pictures/raw/master/udacity-deeplearning/skip-gram.jpg)

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'a', 'term', 'of', 'originated', 'as', 'term']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.428883
# Nearest to i: hear, shortest, hexokinase, gaspar, blow, hanse, esther, councillor,
# Nearest to zero: hendrix, indeterminate, lair, lettering, topic, widgery, transvestite, mineralogical,
# Nearest to into: impeded, goat, tricity, couscous, fondness, tutti, specializations, lone,
# Nearest to b: fripp, desmond, gripped, pictorial, justus, froze, lomborg, riff,
# Nearest to world: amide, paramilitaries, kobayashi, language, emanating, konerko, freedman, investiture,
# Nearest to some: drusilla, medicines, reformists, alibi, immoral, middletown, kombinate, paleozoic,
# Nearest to but: boundary, polonaise, hinayana, hypothyroidism, ung, substantiate, lagrand, eject,
# Nearest to after: coded, grasshopper, lisa, althing, mobs, coincidental, murat, ibsen,
# Nearest to three: tsvetaeva, vinge, solanas, agung, watchtower, upheavals, peloponnesus, vendors,
# Nearest to about: molecule, playfair, directorial, emits, multiples, vehicle, parade, epilogue,
# Nearest to there: bmp, thither, specializations, frail, dillon, aquarius, designed, existential,
# Nearest to UNK: trades, eugenia, councilors, counting, enactment, fugitive, publisher, katharina,
# Nearest to of: somatic, sample, texts, cherokees, captive, medicinal, doth, foregoing,
# Nearest to new: cantonal, mayan, licensure, cattle, wali, com, aeronautical, tines,
# Nearest to years: interpret, remember, fathers, mold, belushi, billed, lasers, lizards,
# Nearest to he: mage, het, causation, worshipped, monaghan, leq, lisp, xena,
# Average loss at step 2000: 4.366401
# Average loss at step 4000: 3.864455
# Average loss at step 6000: 3.789865
# Average loss at step 8000: 3.689334
# Average loss at step 10000: 3.622782
# Nearest to i: esther, you, merv, poseidon, intoxicated, hutcheson, southward, shortest,
# Nearest to zero: five, nine, eight, six, seven, four, three, two,
# Nearest to into: with, impeded, couscous, linguistics, from, sovereigns, chests, craftsmen,
# Nearest to b: froze, english, cath, bearers, toland, shipments, zacharias, d,
# Nearest to world: haider, leather, shortly, jumblatt, meanwhile, vhf, concludes, intellectualism,
# Nearest to some: summaries, many, all, completing, mentality, doctorow, reformists, these,
# Nearest to but: boundary, hinayana, nurse, which, blinded, heidi, burundi, architectures,
# Nearest to after: enthroned, ucl, newborn, navigators, resurgent, gielgud, diethyl, concatenation,
# Nearest to three: seven, six, four, eight, five, two, nine, zero,
# Nearest to about: wap, fest, evaporates, shakespearean, whilst, decrypted, ircii, sns,
# Nearest to there: it, he, they, that, thither, designed, lubricant, meo,
# Nearest to UNK: nominative, al, inside, extraction, dig, fatty, lombardy, csv,
# Nearest to of: in, for, and, slums, rubin, on, gyeongsang, pediatrics,
# Nearest to new: com, farms, tines, licensure, cantonal, hagi, djbdns, extremes,
# Nearest to years: remember, fathers, mold, mcenroe, osbourne, nicknames, bhakti, ghetto,
# Nearest to he: it, she, they, there, who, leq, consultants, occurred,
# Average loss at step 12000: 3.605927
# Average loss at step 14000: 3.572964
# Average loss at step 16000: 3.411397
# Average loss at step 18000: 3.457734
# Average loss at step 20000: 3.538369
# Nearest to i: esther, you, ii, mahommed, antiquark, they, intoxicated, eduardo,
# Nearest to zero: five, six, four, seven, three, eight, nine, two,
# Nearest to into: with, from, after, linguistics, under, impeded, banana, kn,
# Nearest to b: d, trs, froze, mispronounced, nonzero, mislead, toland, ath,
# Nearest to world: leather, shortly, interscope, haider, conditioning, ouster, berlin, kongo,
# Nearest to some: many, these, all, several, their, its, summaries, other,
# Nearest to but: however, which, that, and, while, hinayana, there, included,
# Nearest to after: from, ucl, before, into, newborn, during, jamaat, navigators,
# Nearest to three: four, five, two, seven, six, eight, zero, one,
# Nearest to about: wap, shakespearean, ircii, rodolfo, katanga, discrete, fest, mansions,
# Nearest to there: it, they, he, not, also, still, which, nabataean,
# Nearest to UNK: alleviation, chilean, nominative, navarro, formative, decipherment, windmills, ewell,
# Nearest to of: and, in, for, gyeongsang, including, rubin, cherokees, taxonomy,
# Nearest to new: com, djbdns, hagi, tines, aeronautical, extremes, farms, surrogate,
# Nearest to years: days, remember, ghetto, fathers, osbourne, frederic, mold, belushi,
# Nearest to he: it, she, they, who, there, leq, consultants, unbelievers,
# Average loss at step 22000: 3.510159
# Average loss at step 24000: 3.492769
# Average loss at step 26000: 3.477708
# Average loss at step 28000: 3.483075
# Average loss at step 30000: 3.501906
# Nearest to i: ii, you, esther, we, antiquark, bmi, intoxicated, externally,
# Nearest to zero: five, four, seven, eight, six, nine, two, three,
# Nearest to into: from, under, with, kn, banana, softened, impeded, after,
# Nearest to b: d, mispronounced, toland, nonzero, shipments, trs, prospered, buzz,
# Nearest to world: shortly, election, battle, kongo, book, engages, enthusiastically, haider,
# Nearest to some: many, these, several, all, their, any, spellings, most,
# Nearest to but: however, and, though, while, although, which, or, that,
# Nearest to after: before, during, when, from, ten, into, centralization, ucl,
# Nearest to three: four, five, eight, six, seven, two, nine, zero,
# Nearest to about: wap, katanga, codecs, between, outlived, ircii, discrete, postmodern,
# Nearest to there: they, it, still, he, usually, also, not, we,
# Nearest to UNK: recalcitrant, proceeding, aol, beats, charles, healthcare, psychiatrist, glide,
# Nearest to of: in, for, and, including, greatest, entire, rubin, pediatrics,
# Nearest to new: com, surrogate, tines, conduit, comical, hagi, rko, extremes,
# Nearest to years: days, months, ghetto, decades, lix, times, screenings, imperialism,
# Nearest to he: it, she, they, who, there, leq, never, unbelievers,
# Average loss at step 32000: 3.500267
# Average loss at step 34000: 3.495413
# Average loss at step 36000: 3.455016
# Average loss at step 38000: 3.303327
# Average loss at step 40000: 3.430300
# Nearest to i: you, ii, we, t, antiquark, they, esther, he,
# Nearest to zero: seven, five, eight, four, nine, six, three, two,
# Nearest to into: kn, impeded, banana, from, payload, couscous, under, after,
# Nearest to b: d, c, UNK, clamps, x, milos, r, mod,
# Nearest to world: shortly, cold, election, engages, kongo, vietnam, stacks, leagues,
# Nearest to some: many, several, these, their, various, any, both, spellings,
# Nearest to but: however, and, though, although, while, which, it, yet,
# Nearest to after: before, during, when, jamaat, sombart, into, from, for,
# Nearest to three: four, five, seven, two, six, eight, nine, zero,
# Nearest to about: wap, katanga, outlived, ircii, codecs, over, on, unethical,
# Nearest to there: they, it, he, still, now, usually, often, she,
# Nearest to UNK: b, o, asa, cravings, n, fragrance, de, aztecs,
# Nearest to of: in, jacky, pediatrics, for, slums, quicksort, guts, registering,
# Nearest to new: hagi, tines, stomach, rko, copylefted, extremes, status, upbringing,
# Nearest to years: days, months, decades, times, ghetto, lix, year, screenings,
# Nearest to he: she, it, they, there, who, leq, unbelievers, i,
# Average loss at step 42000: 3.437579
# Average loss at step 44000: 3.455149
# Average loss at step 46000: 3.448190
# Average loss at step 48000: 3.355033
# Average loss at step 50000: 3.383705
# Nearest to i: you, ii, we, t, esther, unhealthy, g, externally,
# Nearest to zero: seven, five, eight, six, four, nine, three, two,
# Nearest to into: from, through, softened, under, joey, kn, after, chang,
# Nearest to b: d, x, c, r, milos, h, sartre, f,
# Nearest to world: cold, engages, vietnam, copylefted, liberal, election, kongo, stacks,
# Nearest to some: many, several, these, both, various, those, most, their,
# Nearest to but: however, although, while, though, and, that, when, than,
# Nearest to after: before, when, during, while, jamaat, from, into, if,
# Nearest to three: four, seven, six, two, eight, five, nine, zero,
# Nearest to about: katanga, rodolfo, over, wap, planting, between, discrete, ircii,
# Nearest to there: it, they, he, still, now, which, she, these,
# Nearest to UNK: nominative, fantasyland, irving, rhone, lesion, g, bruised, dr,
# Nearest to of: in, including, outer, and, zander, pediatrics, malatesta, greatest,
# Nearest to new: copylefted, musical, comical, resettle, hagi, ghilzai, marsupials, stomach,
# Nearest to years: days, months, decades, times, year, lix, bogot, however,
# Nearest to he: she, it, they, who, there, this, unbelievers, never,
# Average loss at step 52000: 3.436975
# Average loss at step 54000: 3.425536
# Average loss at step 56000: 3.438629
# Average loss at step 58000: 3.402726
# Average loss at step 60000: 3.391708
# Nearest to i: ii, you, we, g, t, they, esther, bmi,
# Nearest to zero: five, four, six, eight, seven, nine, three, two,
# Nearest to into: through, from, banana, under, kn, within, over, couscous,
# Nearest to b: d, c, n, r, x, h, racks, matriculation,
# Nearest to world: cold, vietnam, liberal, nation, shortly, constitution, copylefted, falklands,
# Nearest to some: many, several, these, most, all, various, any, both,
# Nearest to but: however, although, and, though, than, which, while, too,
# Nearest to after: before, during, when, while, under, without, if, jamaat,
# Nearest to three: five, four, six, eight, seven, two, nine, one,
# Nearest to about: over, rodolfo, outlived, katanga, discrete, developments, necessitating, toffler,
# Nearest to there: they, it, now, still, he, often, we, this,
# Nearest to UNK: nominative, psychometrics, ailment, quinlan, maximized, archive, thickly, organic,
# Nearest to of: for, in, including, ciuszko, verdean, entire, macleod, jacky,
# Nearest to new: hagi, comical, musical, particular, ghilzai, resettle, upbringing, golden,
# Nearest to years: days, months, decades, times, year, lix, bogot, screenings,
# Nearest to he: she, it, they, there, who, unbelievers, later, we,
# Average loss at step 62000: 3.238159
# Average loss at step 64000: 3.257621
# Average loss at step 66000: 3.407608
# Average loss at step 68000: 3.392312
# Average loss at step 70000: 3.363975
# Nearest to i: you, ii, we, g, t, bmi, unhealthy, frac,
# Nearest to zero: five, eight, six, four, seven, nine, three, mbit,
# Nearest to into: through, banana, from, under, nei, kn, within, joey,
# Nearest to b: d, r, x, w, f, racks, milos, c,
# Nearest to world: book, vietnam, nation, cold, copylefted, partitive, enthusiastically, shortly,
# Nearest to some: many, several, these, all, various, any, most, their,
# Nearest to but: however, although, though, which, that, and, than, while,
# Nearest to after: before, during, when, while, without, within, until, smyrnaeans,
# Nearest to three: four, two, six, five, seven, eight, nine, zero,
# Nearest to about: over, outlived, rodolfo, discrete, gathering, katanga, necessitating, that,
# Nearest to there: it, they, we, still, usually, now, he, she,
# Nearest to UNK: navajo, incalculable, handfasting, input, lesion, references, violently, nominative,
# Nearest to of: including, include, ciuszko, outer, jacky, like, crucifixes, verdean,
# Nearest to new: hagi, comical, particular, resettle, upbringing, adventurous, scandal, ghilzai,
# Nearest to years: days, months, decades, year, times, lix, watchman, minutes,
# Nearest to he: she, it, they, there, who, later, we, eventually,
# Average loss at step 72000: 3.374350
# Average loss at step 74000: 3.351428
# Average loss at step 76000: 3.318800
# Average loss at step 78000: 3.355436
# Average loss at step 80000: 3.379292
# Nearest to i: ii, you, we, g, esther, t, frac, manama,
# Nearest to zero: seven, five, six, four, eight, three, nine, two,
# Nearest to into: through, from, within, banana, under, across, over, joey,
# Nearest to b: d, c, r, milos, racks, w, car, contraceptive,
# Nearest to world: vietnam, u, championship, partitive, cold, nation, shortly, copylefted,
# Nearest to some: many, several, most, various, these, any, both, all,
# Nearest to but: however, although, and, though, than, yet, while, they,
# Nearest to after: before, during, when, while, without, until, despite, in,
# Nearest to three: six, five, four, seven, eight, two, nine, zero,
# Nearest to about: over, armature, necessitating, katanga, deepened, unethical, augustan, partit,
# Nearest to there: it, they, he, we, usually, still, she, now,
# Nearest to UNK: e, macdonald, alzheimer, jackson, le, dr, nominative, catalogues,
# Nearest to of: verdean, entire, requesting, including, in, polarity, luis, unlicensed,
# Nearest to new: particular, hagi, comical, tines, chopping, iis, upbringing, golden,
# Nearest to years: days, months, decades, times, minutes, year, weeks, mentality,
# Nearest to he: she, it, they, who, there, we, consultants, never,
# Average loss at step 82000: 3.404204
# Average loss at step 84000: 3.410813
# Average loss at step 86000: 3.389064
# Average loss at step 88000: 3.351003
# Average loss at step 90000: 3.365584
# Nearest to i: you, ii, we, g, esther, frac, ducal, t,
# Nearest to zero: seven, five, eight, six, four, nine, three, u,
# Nearest to into: through, from, banana, within, joey, across, under, dial,
# Nearest to b: d, r, c, h, k, milos, unheated, racks,
# Nearest to world: shortly, partitive, orders, copylefted, nation, vietnam, europe, championship,
# Nearest to some: many, several, these, any, most, all, those, various,
# Nearest to but: however, and, though, although, esdi, which, they, netware,
# Nearest to after: before, during, when, while, until, without, within, if,
# Nearest to three: four, two, five, seven, eight, six, nine, one,
# Nearest to about: over, unethical, armature, katanga, outlived, till, necessitating, revivalist,
# Nearest to there: they, it, he, still, we, now, generally, sometimes,
# Nearest to UNK: irving, belshazzar, butler, jordan, wynette, hartley, vices, besson,
# Nearest to of: for, verdean, including, pediatrics, in, spat, malatesta, clad,
# Nearest to new: particular, golden, specific, hagi, dispense, comical, funnel, entrenched,
# Nearest to years: days, months, decades, minutes, times, year, weeks, centuries,
# Nearest to he: she, it, they, there, who, we, consultants, later,
# Average loss at step 92000: 3.398327
# Average loss at step 94000: 3.253623
# Average loss at step 96000: 3.356193
# Average loss at step 98000: 3.242581
# Average loss at step 100000: 3.358779
# Nearest to i: we, ii, you, they, tweed, frac, g, esther,
# Nearest to zero: five, seven, four, eight, six, nine, three, two,
# Nearest to into: through, from, within, across, in, banana, under, closest,
# Nearest to b: d, mispronounced, tillman, nonzero, hampton, diphtheria, buzz, conjugated,
# Nearest to world: championship, partitive, u, nation, country, shortly, book, vietnam,
# Nearest to some: many, several, these, any, various, all, those, their,
# Nearest to but: however, although, though, and, while, where, which, gard,
# Nearest to after: before, during, when, without, while, despite, sombart, until,
# Nearest to three: four, five, six, seven, eight, two, nine, zero,
# Nearest to about: over, tossing, biographical, outlived, unethical, armature, revivalist, katanga,
# Nearest to there: they, it, he, we, now, still, sometimes, generally,
# Nearest to UNK: thwarted, incalculable, abul, uptown, ba, se, skelton, appian,
# Nearest to of: including, in, verdean, includes, entire, kiritimati, requesting, and,
# Nearest to new: specific, hagi, comical, particular, resettle, tarnished, entrenched, taxing,
# Nearest to years: days, months, decades, minutes, year, times, weeks, centuries,
# Nearest to he: she, it, they, who, there, we, never, rainey,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
