# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
print(' '.join(words[0:100]))
# Out:
# Data size 17005207
# anarchism originated as a term of abuse first used against early working class radicals including the diggers of the english revolution and the sans culottes of the french revolution whilst the term is still used in a pejorative way to describe any act that used violent means to destroy the organization of society it has also been taken up as a positive label by self defined anarchists the word anarchism is derived from the greek without archons ruler chief king anarchism as a political philosophy is the belief that rulers are unnecessary and should be abolished although there are differing

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'a', 'term', 'term', 'originated', 'as', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.143213
# Nearest to have: pergamum, minurso, kx, existence, purchases, letter, slogans, commodities,
# Nearest to called: risking, pharmaceuticals, dannebrog, transfusions, commitment, apple, aligned, catalyze,
# Nearest to was: servers, isis, mohs, poudre, unscathed, besson, chronicon, saumur,
# Nearest to than: aboriginals, nobita, february, discriminate, tycoon, achievable, jai, zquez,
# Nearest to such: machinima, cabinet, societal, hco, ineffectiveness, hispaniola, dismay, finnegans,
# Nearest to i: retinal, catfish, hodge, omer, oyly, booth, couscous, raphaelite,
# Nearest to all: igg, infty, outmoded, maser, narrators, sidearm, fault, xi,
# Nearest to three: frankfort, fram, troopers, farina, abnormally, preserve, metro, legionaries,
# Nearest to many: vignettes, convenient, fatal, seashore, prosper, outward, formulaic, beds,
# Nearest to that: adventist, mutation, judges, puff, residence, ignatius, symbolise, pres,
# Nearest to between: indeed, manuscripts, bcg, separators, usurp, production, epsilon, fansite,
# Nearest to two: brahmaputra, ffffff, rhapsody, thanking, luis, coffee, bsd, pentium,
# Nearest to zero: polyphonic, buds, pronoun, pinch, subvert, bre, willow, nmi,
# Nearest to or: examines, foreseen, wend, crack, involuntary, protected, terrence, fatima,
# Nearest to for: zelaya, autobiographies, viol, tvs, omnium, rulers, biddle, ayer,
# Nearest to of: unknowingly, gluck, applause, disparity, lateran, levin, whip, hyperfocal,
# Average loss at step 2000: 4.373628
# Average loss at step 4000: 3.866795
# Average loss at step 6000: 3.797204
# Average loss at step 8000: 3.688974
# Average loss at step 10000: 3.618292
# Nearest to have: be, had, has, are, were, blackberry, unmixed, slogans,
# Nearest to called: pedestal, cliches, enya, catalyze, dbm, rubenstein, membered, pharmaceuticals,
# Nearest to was: is, were, has, by, be, whorf, had, blockers,
# Nearest to than: aboriginals, tms, emphasised, simplify, gorbachev, february, consciousness, catfish,
# Nearest to such: well, legionnaire, hco, annulled, known, anchor, intron, some,
# Nearest to i: t, oyly, furtherance, qualitative, catfish, retinal, booth, manatus,
# Nearest to all: narrators, swamps, intellectuals, changed, torts, examiners, igg, longstreet,
# Nearest to three: four, five, eight, six, two, seven, nine, zero,
# Nearest to many: some, vignettes, phodopus, convenient, evangelicalism, calculators, vince, sworn,
# Nearest to that: which, it, emf, he, zombie, spurs, replicant, insurgent,
# Nearest to between: production, caliber, crippled, with, esteem, joule, epsilon, in,
# Nearest to two: three, four, five, eight, six, nine, one, seven,
# Nearest to zero: nine, eight, seven, five, six, four, three, two,
# Nearest to or: and, s, howard, pledging, veteran, carvings, inadvertently, algemeen,
# Nearest to for: from, zelaya, of, with, delimitation, helmets, learning, ignaz,
# Nearest to of: in, same, unknowingly, sarah, workable, for, entire, asylum,
# Average loss at step 12000: 3.606209
# Average loss at step 14000: 3.568118
# Average loss at step 16000: 3.413022
# Average loss at step 18000: 3.463131
# Average loss at step 20000: 3.540996
# Nearest to have: had, has, are, be, were, unmixed, referred, commodities,
# Nearest to called: pedestal, cliches, enya, membered, orchards, travers, baskets, demotic,
# Nearest to was: is, were, has, had, be, torque, been, became,
# Nearest to than: or, catfish, emphasised, lullaby, aboriginals, kolkata, jai, gorbachev,
# Nearest to such: well, known, legionnaire, these, sittings, annulled, montgomery, some,
# Nearest to i: ii, t, we, corner, purr, stanis, ke, manatus,
# Nearest to all: many, these, some, shula, intellectuals, several, colossal, their,
# Nearest to three: four, six, five, seven, two, eight, nine, zero,
# Nearest to many: some, several, these, all, other, vignettes, phodopus, legionnaire,
# Nearest to that: which, zombie, emf, but, spurs, when, inmates, what,
# Nearest to between: from, with, in, crippled, caliber, tib, usurp, along,
# Nearest to two: three, four, five, six, eight, seven, one, nine,
# Nearest to zero: five, six, four, seven, eight, three, nine, two,
# Nearest to or: and, than, carvings, howard, for, kathleen, parallel, incorruptible,
# Nearest to for: with, hotter, zelaya, as, of, from, or, by,
# Nearest to of: unknowingly, entire, workable, for, same, in, borealis, ret,
# Average loss at step 22000: 3.498940
# Average loss at step 24000: 3.492160
# Average loss at step 26000: 3.481189
# Average loss at step 28000: 3.483680
# Average loss at step 30000: 3.507863
# Nearest to have: had, has, were, are, be, having, referred, get,
# Nearest to called: pedestal, voc, enya, named, baskets, airs, membered, cliches,
# Nearest to was: is, had, were, became, has, been, when, by,
# Nearest to than: lullaby, catfish, or, emphasised, aboriginals, bony, jai, kolkata,
# Nearest to such: well, these, known, legionnaire, annulled, sittings, some, montgomery,
# Nearest to i: ii, t, we, huggins, reductive, inferential, iii, they,
# Nearest to all: these, many, several, some, shula, location, various, equally,
# Nearest to three: four, five, seven, six, two, eight, nine, zero,
# Nearest to many: some, several, these, various, all, most, those, their,
# Nearest to that: which, emf, this, replicant, what, pangaea, however, zombie,
# Nearest to between: with, in, crippled, around, endowment, backbench, caliber, comte,
# Nearest to two: four, three, one, six, five, seven, eight, nine,
# Nearest to zero: five, seven, four, eight, six, three, nine, two,
# Nearest to or: and, overrides, than, pledging, but, cam, twas, fredrik,
# Nearest to for: zelaya, when, hotter, incorruptible, from, with, after, of,
# Nearest to of: in, unknowingly, workable, nosed, from, entire, borealis, ret,
# Average loss at step 32000: 3.498669
# Average loss at step 34000: 3.494828
# Average loss at step 36000: 3.453912
# Average loss at step 38000: 3.304956
# Average loss at step 40000: 3.429596
# Nearest to have: had, has, were, are, be, unmixed, include, clearly,
# Nearest to called: named, devout, considered, enya, leadbelly, pedestal, shootings, where,
# Nearest to was: is, were, had, has, became, been, be, torque,
# Nearest to than: or, lullaby, catfish, aboriginals, emphasised, relatively, candidate, releasing,
# Nearest to such: well, these, known, including, legionnaire, coated, ineffectiveness, annulled,
# Nearest to i: we, ii, t, you, they, inferential, he, meditating,
# Nearest to all: many, these, both, longstreet, several, out, shula, riot,
# Nearest to three: four, seven, six, five, two, eight, nine, zero,
# Nearest to many: some, several, these, various, those, all, both, their,
# Nearest to that: which, what, where, however, this, emf, when, zombie,
# Nearest to between: with, around, in, at, along, trojan, from, mythic,
# Nearest to two: four, three, six, five, seven, eight, nine, one,
# Nearest to zero: five, seven, nine, eight, six, four, three, two,
# Nearest to or: and, than, pledging, metro, neumann, thessaloniki, automata, a,
# Nearest to for: zelaya, of, in, hotter, from, unsaturated, enthalpy, gujarat,
# Nearest to of: workable, for, from, in, unknowingly, damian, internazionale, monotremes,
# Average loss at step 42000: 3.439125
# Average loss at step 44000: 3.453211
# Average loss at step 46000: 3.453772
# Average loss at step 48000: 3.359393
# Average loss at step 50000: 3.380327
# Nearest to have: had, has, were, are, be, include, produce, who,
# Nearest to called: named, devout, enya, benoit, pedestal, prepositions, where, ili,
# Nearest to was: is, were, has, became, had, be, being, been,
# Nearest to than: or, lullaby, catfish, but, much, passau, aboriginals, releasing,
# Nearest to such: well, these, known, many, including, coated, certain, legionnaire,
# Nearest to i: ii, we, you, t, meditating, they, huggins, inferential,
# Nearest to all: both, many, these, some, every, equally, investigator, each,
# Nearest to three: four, seven, six, eight, two, five, nine, zero,
# Nearest to many: some, several, these, various, both, those, all, such,
# Nearest to that: which, what, however, where, replicant, emf, insurgent, this,
# Nearest to between: with, around, in, among, from, crippled, croatia, along,
# Nearest to two: three, four, six, eight, one, seven, five, nine,
# Nearest to zero: seven, five, six, eight, four, nine, three, two,
# Nearest to or: and, than, portmanteaus, pledging, carvings, overrides, credentials, inaccuracies,
# Nearest to for: including, zelaya, hotter, incorruptible, until, correspondents, briton, after,
# Nearest to of: workable, in, entire, unknowingly, polyhedron, ret, borealis, nosed,
# Average loss at step 52000: 3.436708
# Average loss at step 54000: 3.429104
# Average loss at step 56000: 3.434622
# Average loss at step 58000: 3.398673
# Average loss at step 60000: 3.393609
# Nearest to have: had, has, were, are, produce, be, include, cultivar,
# Nearest to called: named, used, considered, enya, pedestal, benoit, leadbelly, devout,
# Nearest to was: is, had, became, were, has, torque, be, been,
# Nearest to than: or, lullaby, but, and, much, consciousness, calibre, passau,
# Nearest to such: well, these, known, many, including, certain, ineffectiveness, coated,
# Nearest to i: ii, we, you, t, they, inferential, stanis, meditating,
# Nearest to all: many, every, some, those, both, various, several, these,
# Nearest to three: five, four, six, eight, seven, two, nine, zero,
# Nearest to many: some, several, these, various, all, both, most, such,
# Nearest to that: which, what, this, emf, however, fervent, it, replicant,
# Nearest to between: with, in, among, around, within, from, over, croatia,
# Nearest to two: three, four, one, six, five, eight, seven, nine,
# Nearest to zero: five, four, seven, eight, six, nine, three, two,
# Nearest to or: and, than, bryozoa, pledging, manifold, hydrothermal, traffic, automata,
# Nearest to for: including, hotter, zelaya, danmarks, to, when, of, ding,
# Nearest to of: in, unknowingly, pt, workable, including, nosed, same, for,
# Average loss at step 62000: 3.241863
# Average loss at step 64000: 3.256437
# Average loss at step 66000: 3.402236
# Average loss at step 68000: 3.397129
# Average loss at step 70000: 3.360855
# Nearest to have: had, has, were, are, include, produce, be, require,
# Nearest to called: named, enya, considered, devout, libro, sohn, leadbelly, pedestal,
# Nearest to was: is, has, were, had, been, became, when, be,
# Nearest to than: lullaby, or, but, passau, andechs, while, consciousness, and,
# Nearest to such: these, well, known, certain, many, including, some, cited,
# Nearest to i: ii, we, you, g, they, letterboxes, t, sloping,
# Nearest to all: every, many, some, various, both, those, several, any,
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Nearest to many: some, several, various, these, all, numerous, both, most,
# Nearest to that: which, what, however, this, but, emf, where, often,
# Nearest to between: with, around, among, within, from, into, in, over,
# Nearest to two: three, four, six, five, seven, one, eight, nine,
# Nearest to zero: five, four, six, eight, seven, nine, three, two,
# Nearest to or: and, than, but, tisdall, gard, while, any, without,
# Nearest to for: including, zelaya, hotter, in, while, from, to, helmets,
# Nearest to of: including, unknowingly, actual, monotremes, for, original, damian, anthropic,
# Average loss at step 72000: 3.372193
# Average loss at step 74000: 3.348600
# Average loss at step 76000: 3.305808
# Average loss at step 78000: 3.350646
# Average loss at step 80000: 3.386882
# Nearest to have: had, has, are, be, were, include, offer, recognize,
# Nearest to called: named, considered, known, used, benoit, devout, leadbelly, closed,
# Nearest to was: is, became, were, had, be, doping, has, being,
# Nearest to than: lullaby, much, while, and, or, passau, emphasised, but,
# Nearest to such: well, these, certain, known, including, follows, many, cited,
# Nearest to i: ii, you, we, t, they, inferential, meditating, iii,
# Nearest to all: many, both, every, several, various, some, these, any,
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Nearest to many: several, some, various, these, all, most, both, numerous,
# Nearest to that: which, however, what, emf, fervent, but, zombie, replicant,
# Nearest to between: among, with, around, within, over, in, from, ccf,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Nearest to zero: seven, five, six, four, eight, three, nine, two,
# Nearest to or: and, spotless, than, though, while, overrides, gard, revisited,
# Nearest to for: including, hotter, against, unsaturated, zelaya, memorabilia, bresson, rnsson,
# Nearest to of: including, in, damian, entire, nosed, workable, original, under,
# Average loss at step 82000: 3.406380
# Average loss at step 84000: 3.403982
# Average loss at step 86000: 3.391282
# Average loss at step 88000: 3.351231
# Average loss at step 90000: 3.368933
# Nearest to have: had, has, be, were, are, produce, provide, having,
# Nearest to called: named, considered, used, known, referred, sohn, leadbelly, benoit,
# Nearest to was: is, became, had, were, has, be, been, torque,
# Nearest to than: lullaby, much, passau, or, bony, calibre, andechs, electress,
# Nearest to such: well, known, certain, these, follows, coated, cited, including,
# Nearest to i: ii, we, t, you, g, iv, weisstein, meditating,
# Nearest to all: both, many, several, some, every, various, these, those,
# Nearest to three: four, five, two, seven, eight, six, nine, zero,
# Nearest to many: several, some, various, these, all, most, numerous, both,
# Nearest to that: which, however, what, emf, fervent, nourishment, zombie, replicant,
# Nearest to between: with, within, among, around, over, in, under, into,
# Nearest to two: three, four, five, six, seven, eight, one, nine,
# Nearest to zero: five, seven, six, eight, four, nine, three, two,
# Nearest to or: and, but, gard, overrides, spotless, horizontally, than, tisdall,
# Nearest to for: including, zelaya, against, while, during, of, when, correspondents,
# Nearest to of: including, workable, in, for, unknowingly, actual, pt, iommi,
# Average loss at step 92000: 3.395318
# Average loss at step 94000: 3.258540
# Average loss at step 96000: 3.354754
# Average loss at step 98000: 3.245036
# Average loss at step 100000: 3.355949
# Nearest to have: had, has, were, be, are, produce, require, tend,
# Nearest to called: named, used, considered, referred, devout, libro, benoit, slocum,
# Nearest to was: is, became, has, were, been, torque, when, had,
# Nearest to than: or, lullaby, and, much, even, bryozoa, while, precisely,
# Nearest to such: known, well, certain, including, these, follows, coated, opposed,
# Nearest to i: we, you, ii, they, t, meditating, iv, medallist,
# Nearest to all: many, several, various, these, some, both, every, those,
# Nearest to three: four, five, six, eight, seven, two, nine, zero,
# Nearest to many: several, some, various, all, these, numerous, few, certain,
# Nearest to that: which, however, what, emf, replicant, pangaea, but, who,
# Nearest to between: with, around, among, over, within, fleischer, into, in,
# Nearest to two: four, six, three, five, seven, eight, one, nine,
# Nearest to zero: five, four, eight, six, seven, nine, three, two,
# Nearest to or: and, than, gard, bua, but, energetic, overrides, nor,
# Nearest to for: including, when, zelaya, until, after, during, at, if,
# Nearest to of: including, in, efficacious, and, gives, workable, episcopal, although,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
